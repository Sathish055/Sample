# %%
import os
import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
IMAGE_PATH=input("Enter the URL or File path of the image file:")
# Out:
# Enter the URL or File path of the image file:C:\images\computer.jpg

# %%
IMAGE_PATH
# Out:
# 'C:\\images\\computer.jpg'

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(IMAGE_PATH)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[254, 0], [734, 0], [734, 139], [254, 139]],
#   'TeTH77|',
#   0.021564939356625536),
#  ([[46, 112], [128, 112], [128, 188], [46, 188]], '66', 0.6277598968558057),
#  ([[318, 105], [550, 105], [550, 246], [318, 246]],
#   'Frort',
#   0.07034631934466452),
#  ([[50, 239], [686, 239], [686, 319], [50, 319]],
#   'Computers are able to see,',
#   0.9359577964984884),
#  ([[187, 306], [552, 306], [552, 374], [187, 374]],
#   'hear and learn:',
#   0.6435696312205349),
#  ([[102, 368], [637, 368], [637, 435], [102, 435]],
#   'Welcome to the future:',
#   0.6871823058787819),
#  ([[293, 461], [465, 461], [465, 499], [293, 499]],
#   'Dave Waters',
#   0.6269978563234264),
#  ([[200, 667], [494, 667], [494, 699], [200, 699]],
#   'evolvemachinelearners com',
#   0.8358612092781039)]

# %%
img = cv2.imread(IMAGE_PATH)
spacer = 100
for detection in result: 
    top_left = tuple(detection[0][0])
    bottom_right = tuple(detection[0][2])
    text = detection[1]
    img = cv2.rectangle(img,top_left,bottom_right,(0,255,0),3)
    img = cv2.putText(img,text,(20,spacer), font, 0.5,(0,255,0),2,cv2.LINE_AA)
    spacer+=15
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
